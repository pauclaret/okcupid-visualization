# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("okcupid_profiles.csv")

# %%
df.head(2)
# Out:
#    age  status sex orientation       body_type               diet    drinks  \
# 0   22  single   m    straight  a little extra  strictly anything  socially
# 1   35  single   m    straight         average       mostly other     often
#
#        drugs                      education     ethnicity  ...  \
# 0      never  working on college/university  asian, white  ...
# 1  sometimes          working on space camp         white  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
#
# [2 rows x 31 columns]

# %% [markdown]
# Formating and Cleaning Data

# %%
df.isna().sum()
# Out:
# age                0
# status             0
# sex                0
# orientation        0
# body_type       5296
# diet           24395
# drinks          2985
# drugs          14080
# education       6628
# ethnicity       5680
# height             3
# income             0
# job             8198
# last_online        0
# location           0
# offspring      35561
# pets           19921
# religion       20226
# sign           11056
# smokes          5512
# speaks            50
# essay0          5488
# essay1          7572
# essay2          9638
# essay3         11476
# essay4         10537
# essay5         10850
# essay6         13771
# essay7         12451
# essay8         19225
# essay9         12603
# dtype: int64

# %%
# Renaming columns
columns = ["body_type", "diet", "education", "drinks", "drugs","ethnicity", "job","offspring","pets","religion", "sign", "smokes", "speaks"]

# Filling NaN values
df[columns] = df[columns].fillna("No info")
df["height"] = df["height"].fillna(0)
df["income"] = df["income"].replace(-1, 0)

# Creating a new column by combining essays into one profile text
df["profile_text"] = (df["essay0"].str.cat(df.iloc[:,22:-1].astype(str), sep=" "))

# Deleting unnecessary essays columns, as now I have all of them together in the profile_text column
df = df.drop(df.iloc[:,21:-1], axis=1)
df["profile_text"]=df["profile_text"].fillna("No info")

# Creating a new column by counting the words in the profile_text column
df["total_words"]=df["profile_text"].str.split().str.len()

# Splitting the location column by the comma and taking the first element of the split (the city). This will help us with the map in Tableau
df["location"] = df["location"].str.split(",").str[0]

df.drop_duplicates()

df.head(2)
# Out:
#    age  status sex orientation       body_type               diet    drinks  \
# 0   22  single   m    straight  a little extra  strictly anything  socially
# 1   35  single   m    straight         average       mostly other     often
#
#        drugs                      education     ethnicity  ...  \
# 0      never  working on college/university  asian, white  ...
# 1  sometimes          working on space camp         white  ...
#
#         last_online             location  \
# 0  2012-06-28-20-30  south san francisco
# 1  2012-06-29-21-41              oakland
#
#                                 offspring                       pets  \
# 0  doesn't have kids, but might want them  likes dogs and likes cats
# 1  doesn't have kids, but might want them  likes dogs and likes cats
#
#                                    religion    sign     smokes  \
# 0     agnosticism and very serious about it  gemini  sometimes
# 1  agnosticism but not too serious about it  cancer         no
#
#                                               speaks  \
# 0                                            english
# 1  english (fluently), spanish (poorly), french (...
#
#                                         profile_text total_words
# 0  about me:  i would love to think that i was so...         420
# 1  i am a chef: this is what that means. 1. i am ...         271
#
# [2 rows x 23 columns]

# %%
# Checking again
df.isna().sum()
# Out:
# age             0
# status          0
# sex             0
# orientation     0
# body_type       0
# diet            0
# drinks          0
# drugs           0
# education       0
# ethnicity       0
# height          0
# income          0
# job             0
# last_online     0
# location        0
# offspring       0
# pets            0
# religion        0
# sign            0
# smokes          0
# speaks          0
# profile_text    0
# total_words     0
# dtype: int64

# %% [markdown]
# General Statistics and Data Types

# %%
df.describe().T
# Out:
#                count          mean           std   min    25%    50%    75%  \
# age          59946.0     32.340290      9.452779  18.0   26.0   30.0   37.0
# height       59946.0     68.291863      4.023813   0.0   66.0   68.0   71.0
# income       59946.0  20034.030628  97346.025793   0.0    0.0    0.0    0.0
# total_words  59946.0    323.728706    275.302965   2.0  138.0  274.0  445.0
#
#                    max
# age              110.0
# height            95.0
# income       1000000.0
# total_words     9511.0

# %%
df.describe(include = "object").T
# Out:
#               count unique                                top   freq
# status        59946      5                             single  55697
# sex           59946      2                                  m  35829
# orientation   59946      3                           straight  51606
# body_type     59946     13                            average  14652
# diet          59946     19                            No info  24395
# drinks        59946      7                           socially  41780
# drugs         59946      4                              never  37724
# education     59946     33  graduated from college/university  23959
# ethnicity     59946    218                              white  32831
# job           59946     22                            No info   8198
# last_online   59946  30123                   2012-06-29-22-56     24
# location      59946    198                      san francisco  31064
# offspring     59946     16                            No info  35561
# pets          59946     16                            No info  19921
# religion      59946     46                            No info  20226
# sign          59946     49                            No info  11056
# smokes        59946      6                                 no  43896
# speaks        59946   7648                            english  21828
# profile_text  59946  54451                            No info   5488

# %%
# On average, the age of profile's is 32 years old, with the income around 20.000$
# Average number of words in each biography is 323

# %%
df.to_csv('cleaned.csv', index=False)
